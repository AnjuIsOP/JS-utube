# %% [markdown]
# <a href="https://colab.research.google.com/github/AnjuIsOP/JS-utube/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel("PDAD.xlsx",header=1)
df
# Out:
#     GROUP NO.                          IT PROJECT TOPIC   \
# 0            1        FOOD DELIVERY APP (HOTEL BIG BOSS)
# 1            2                      VIT MAIN CANTEEN(UI)
# 2            3                   PAINTS AND PLYWOODS APP
# 3            4                                       NaN
# 4            5                           JEWELLERY STORE
# 5            6            TABLE BOOKING APP(BookMyTable)
# 6            7        E-BIKE DEALERSHIP WEBSITE(EZYRIDE)
# 7            8  ONLINE BOOK BUYING WEBSITE(THE BOOKLAND)
# 8            9                                       NaN
# 9           10                                       NaN
# 10          11            COFFEE AND SNACKS DELIVERY APP
# 11          12                                       NaN
# 12          13                FOOD DELIVERY APP (FOODIE)
# 13          14                                       NaN
#
#                       NON IT PROJECT TOPIC
# 0                       BLACK BOARD DUSTER
# ...

# %%
df['2018-02-HomeValue'].max()
# Out:
# 1055699.826634386

# %%
df['2018-03-CutRaw'].mean()
# Out:
# 7777.5564263322885

# %%
weather_data = {
    'day' :['monday','tuesday','wednesday','thursday','friday','saturday'],
    'date' : ['1/07/2025','2/07/2025','3/07/2025','4/07/2025','5/07/2025','6/07/2025'],
    'temperature' : [43,34,44,42,40,36]
}
df = pd.DataFrame(weather_data)
df
# Out:
#          day       date  temperature
# 0     monday  1/07/2025           43
# 1    tuesday  2/07/2025           34
# 2  wednesday  3/07/2025           44
# 3   thursday  4/07/2025           42
# 4     friday  5/07/2025           40
# 5   saturday  6/07/2025           36

# %%
df['temperature'].max()
# Out:
# 44

# %%
df['date'][df['day']=="friday"]
# Out:
# 4    5/07/2025
# Name: date, dtype: object

# %%
df.columns
# Out:
# Index(['day', 'date', 'temperature'], dtype='object')

# %%
df.describe()
# Out:
#        temperature
# count     6.000000
# mean     39.833333
# std       4.020779
# min      34.000000
# 25%      37.000000
# 50%      41.000000
# 75%      42.750000
# max      44.000000
